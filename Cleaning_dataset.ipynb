# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Data

# %%
# import dataset
path = "/content/NBA_raw_player_data.csv"
data = pd.read_csv(path)

df = pd.DataFrame(data)
df
# Out:
#        Unnamed: 0        Date       Team            Acquired    Relinquished  \
# 0               0  1951-12-25    Bullets                 NaN   Don Barksdale
# 1               1  1952-12-26     Knicks                 NaN   Max Zaslofsky
# 2               2  1956-12-29     Knicks                 NaN   Jim Baechtold
# 3               3  1959-01-16     Lakers                 NaN    Elgin Baylor
# 4               4  1961-11-26     Lakers                 NaN    Elgin Baylor
# ...           ...         ...        ...                 ...             ...
# 37662       37662  2023-04-16   Clippers       Marcus Morris             NaN
# 37663       37663  2023-04-16  Grizzlies       Dillon Brooks             NaN
# 37664       37664  2023-04-16  Grizzlies           Ja Morant             NaN
# 37665       37665  2023-04-16  Grizzlies   Jaren Jackson Jr.             NaN
# 37666       37666  2023-04-16  Grizzlies        Santi Aldama             NaN
#
#                                                    Notes
# 0                                           placed on IL
# 1                     placed on IL with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from IL
# 37663                                  activated from IL
# 37664                                  activated from IL
# 37665                                  activated from IL
# 37666                                  activated from IL
#
# [37667 rows x 6 columns]

# %% [markdown]
# # Clean data

# %%
# drop columns
new_df = df.drop(columns=['Unnamed: 0'])
new_df
# Out:
#              Date       Team            Acquired    Relinquished  \
# 0      1951-12-25    Bullets                 NaN   Don Barksdale
# 1      1952-12-26     Knicks                 NaN   Max Zaslofsky
# 2      1956-12-29     Knicks                 NaN   Jim Baechtold
# 3      1959-01-16     Lakers                 NaN    Elgin Baylor
# 4      1961-11-26     Lakers                 NaN    Elgin Baylor
# ...           ...        ...                 ...             ...
# 37662  2023-04-16   Clippers       Marcus Morris             NaN
# 37663  2023-04-16  Grizzlies       Dillon Brooks             NaN
# 37664  2023-04-16  Grizzlies           Ja Morant             NaN
# 37665  2023-04-16  Grizzlies   Jaren Jackson Jr.             NaN
# 37666  2023-04-16  Grizzlies        Santi Aldama             NaN
#
#                                                    Notes
# 0                                           placed on IL
# 1                     placed on IL with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from IL
# 37663                                  activated from IL
# 37664                                  activated from IL
# 37665                                  activated from IL
# 37666                                  activated from IL
#
# [37667 rows x 5 columns]

# %%
# find where acquired and relinquished are the same
same_values = new_df[new_df['Acquired'].notna() & new_df['Relinquished'].notna()]
same_values
# Out:
#              Date  Team         Acquired     Relinquished              Notes
# 14793  2010-01-16  Jazz   Kyrylo Fesenko   Kyrylo Fesenko  activated from IL

# %%
# rename acquired and relinquished to player name for readability
new_df['player_name'] = new_df[["Acquired", "Relinquished"]].fillna('').sum(axis=1)

# drop acquired and relinquished
new_df = new_df.drop(columns=["Acquired",'Relinquished'])
new_df
# Out:
#              Date       Team  \
# 0      1951-12-25    Bullets
# 1      1952-12-26     Knicks
# 2      1956-12-29     Knicks
# 3      1959-01-16     Lakers
# 4      1961-11-26     Lakers
# ...           ...        ...
# 37662  2023-04-16   Clippers
# 37663  2023-04-16  Grizzlies
# 37664  2023-04-16  Grizzlies
# 37665  2023-04-16  Grizzlies
# 37666  2023-04-16  Grizzlies
#
#                                                    Notes         player_name
# 0                                           placed on IL       Don Barksdale
# 1                     placed on IL with torn side muscle       Max Zaslofsky
# 2                                placed on inactive list       Jim Baechtold
# 3      player refused to play after being denied a ro...        Elgin Baylor
# 4                      player reported for military duty        Elgin Baylor
# ...                                                  ...                 ...
# 37662                                  activated from IL       Marcus Morris
# 37663                                  activated from IL       Dillon Brooks
# 37664                                  activated from IL           Ja Morant
# 37665                                  activated from IL   Jaren Jackson Jr.
# 37666                                  activated from IL        Santi Aldama
#
# [37667 rows x 4 columns]

# %%
# search for nulls
new_df.isnull().sum()
# Out:
# Date           0
# Team           0
# Notes          0
# player_name    0
# dtype: int64

# %%
# rename columns
new_df = new_df.rename(columns={'Date': 'date', 'Team': 'team', 'Notes': 'notes'})
new_df
# Out:
#              date       team  \
# 0      1951-12-25    Bullets
# 1      1952-12-26     Knicks
# 2      1956-12-29     Knicks
# 3      1959-01-16     Lakers
# 4      1961-11-26     Lakers
# ...           ...        ...
# 37662  2023-04-16   Clippers
# 37663  2023-04-16  Grizzlies
# 37664  2023-04-16  Grizzlies
# 37665  2023-04-16  Grizzlies
# 37666  2023-04-16  Grizzlies
#
#                                                    notes         player_name
# 0                                           placed on IL       Don Barksdale
# 1                     placed on IL with torn side muscle       Max Zaslofsky
# 2                                placed on inactive list       Jim Baechtold
# 3      player refused to play after being denied a ro...        Elgin Baylor
# 4                      player reported for military duty        Elgin Baylor
# ...                                                  ...                 ...
# 37662                                  activated from IL       Marcus Morris
# 37663                                  activated from IL       Dillon Brooks
# 37664                                  activated from IL           Ja Morant
# 37665                                  activated from IL   Jaren Jackson Jr.
# 37666                                  activated from IL        Santi Aldama
#
# [37667 rows x 4 columns]

# %%
# change to datetime
new_df['date'] = pd.to_datetime(df.Date)
new_df
# Out:
#             date       team  \
# 0     1951-12-25    Bullets
# 1     1952-12-26     Knicks
# 2     1956-12-29     Knicks
# 3     1959-01-16     Lakers
# 4     1961-11-26     Lakers
# ...          ...        ...
# 37662 2023-04-16   Clippers
# 37663 2023-04-16  Grizzlies
# 37664 2023-04-16  Grizzlies
# 37665 2023-04-16  Grizzlies
# 37666 2023-04-16  Grizzlies
#
#                                                    notes         player_name
# 0                                           placed on IL       Don Barksdale
# 1                     placed on IL with torn side muscle       Max Zaslofsky
# 2                                placed on inactive list       Jim Baechtold
# 3      player refused to play after being denied a ro...        Elgin Baylor
# 4                      player reported for military duty        Elgin Baylor
# ...                                                  ...                 ...
# 37662                                  activated from IL       Marcus Morris
# 37663                                  activated from IL       Dillon Brooks
# 37664                                  activated from IL           Ja Morant
# 37665                                  activated from IL   Jaren Jackson Jr.
# 37666                                  activated from IL        Santi Aldama
#
# [37667 rows x 4 columns]

# %% [markdown]
# # Preprocessing

# %%
# clean notes
new_df['notes_clean'] = new_df['notes'].str.lower().str.replace(r'[^a-z0-9\s]', '', regex=True).str.strip()
new_df
# Out:
#             date       team  \
# 0     1951-12-25    Bullets
# 1     1952-12-26     Knicks
# 2     1956-12-29     Knicks
# 3     1959-01-16     Lakers
# 4     1961-11-26     Lakers
# ...          ...        ...
# 37662 2023-04-16   Clippers
# 37663 2023-04-16  Grizzlies
# 37664 2023-04-16  Grizzlies
# 37665 2023-04-16  Grizzlies
# 37666 2023-04-16  Grizzlies
#
#                                                    notes         player_name  \
# 0                                           placed on IL       Don Barksdale
# 1                     placed on IL with torn side muscle       Max Zaslofsky
# 2                                placed on inactive list       Jim Baechtold
# 3      player refused to play after being denied a ro...        Elgin Baylor
# 4                      player reported for military duty        Elgin Baylor
# ...                                                  ...                 ...
# 37662                                  activated from IL       Marcus Morris
# 37663                                  activated from IL       Dillon Brooks
# 37664                                  activated from IL           Ja Morant
# 37665                                  activated from IL   Jaren Jackson Jr.
# 37666                                  activated from IL        Santi Aldama
#
#                                              notes_clean
# 0                                           placed on il
# 1                     placed on il with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from il
# 37663                                  activated from il
# 37664                                  activated from il
# 37665                                  activated from il
# 37666                                  activated from il
#
# [37667 rows x 5 columns]

# %%
new_df = new_df.drop(columns='notes')
new_df
# Out:
#             date       team         player_name  \
# 0     1951-12-25    Bullets       Don Barksdale
# 1     1952-12-26     Knicks       Max Zaslofsky
# 2     1956-12-29     Knicks       Jim Baechtold
# 3     1959-01-16     Lakers        Elgin Baylor
# 4     1961-11-26     Lakers        Elgin Baylor
# ...          ...        ...                 ...
# 37662 2023-04-16   Clippers       Marcus Morris
# 37663 2023-04-16  Grizzlies       Dillon Brooks
# 37664 2023-04-16  Grizzlies           Ja Morant
# 37665 2023-04-16  Grizzlies   Jaren Jackson Jr.
# 37666 2023-04-16  Grizzlies        Santi Aldama
#
#                                              notes_clean
# 0                                           placed on il
# 1                     placed on il with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from il
# 37663                                  activated from il
# 37664                                  activated from il
# 37665                                  activated from il
# 37666                                  activated from il
#
# [37667 rows x 4 columns]

# %%
# clean names
# fix slashes for more than one name
new_df['player_name'] = new_df['player_name'].str.split('/').str[-1].str.strip()
new_df
# Out:
#             date       team        player_name  \
# 0     1951-12-25    Bullets      Don Barksdale
# 1     1952-12-26     Knicks      Max Zaslofsky
# 2     1956-12-29     Knicks      Jim Baechtold
# 3     1959-01-16     Lakers       Elgin Baylor
# 4     1961-11-26     Lakers       Elgin Baylor
# ...          ...        ...                ...
# 37662 2023-04-16   Clippers      Marcus Morris
# 37663 2023-04-16  Grizzlies      Dillon Brooks
# 37664 2023-04-16  Grizzlies          Ja Morant
# 37665 2023-04-16  Grizzlies  Jaren Jackson Jr.
# 37666 2023-04-16  Grizzlies       Santi Aldama
#
#                                              notes_clean
# 0                                           placed on il
# 1                     placed on il with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from il
# 37663                                  activated from il
# 37664                                  activated from il
# 37665                                  activated from il
# 37666                                  activated from il
#
# [37667 rows x 4 columns]

# %%
# normalize activated and returned to be uniform
# looking for returned in the notes
returned = new_df[new_df['notes_clean'].str.contains('returned', case=False, na=False)]
returned.value_counts().count()
# Out:
# np.int64(3)

# %%
# change returned to activated
new_df['notes_clean'] = new_df['notes_clean'].str.replace('returned to lineup', 'activated', case=False, regex=True)
new_df
# Out:
#             date       team        player_name  \
# 0     1951-12-25    Bullets      Don Barksdale
# 1     1952-12-26     Knicks      Max Zaslofsky
# 2     1956-12-29     Knicks      Jim Baechtold
# 3     1959-01-16     Lakers       Elgin Baylor
# 4     1961-11-26     Lakers       Elgin Baylor
# ...          ...        ...                ...
# 37662 2023-04-16   Clippers      Marcus Morris
# 37663 2023-04-16  Grizzlies      Dillon Brooks
# 37664 2023-04-16  Grizzlies          Ja Morant
# 37665 2023-04-16  Grizzlies  Jaren Jackson Jr.
# 37666 2023-04-16  Grizzlies       Santi Aldama
#
#                                              notes_clean
# 0                                           placed on il
# 1                     placed on il with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from il
# 37663                                  activated from il
# 37664                                  activated from il
# 37665                                  activated from il
# 37666                                  activated from il
#
# [37667 rows x 4 columns]

# %%
# change to activated to be the same
new_df['notes_clean'] = new_df['notes_clean'].str.replace('player returned to team', 'activated', case=False, regex=True)
new_df
# Out:
#             date       team        player_name  \
# 0     1951-12-25    Bullets      Don Barksdale
# 1     1952-12-26     Knicks      Max Zaslofsky
# 2     1956-12-29     Knicks      Jim Baechtold
# 3     1959-01-16     Lakers       Elgin Baylor
# 4     1961-11-26     Lakers       Elgin Baylor
# ...          ...        ...                ...
# 37662 2023-04-16   Clippers      Marcus Morris
# 37663 2023-04-16  Grizzlies      Dillon Brooks
# 37664 2023-04-16  Grizzlies          Ja Morant
# 37665 2023-04-16  Grizzlies  Jaren Jackson Jr.
# 37666 2023-04-16  Grizzlies       Santi Aldama
#
#                                              notes_clean
# 0                                           placed on il
# 1                     placed on il with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from il
# 37663                                  activated from il
# 37664                                  activated from il
# 37665                                  activated from il
# 37666                                  activated from il
#
# [37667 rows x 4 columns]

# %%
activated = new_df[new_df['notes_clean'].str.contains('activated', case=False, na=False)]
activated = activated.rename(columns={'date':'activated'})
activated = activated.drop(columns=['notes_clean'])

activated.count()
# Out:
# activated      17615
# team           17615
# player_name    17615
# dtype: int64

# %%
# get injury notes only
new_df_filtered = new_df[~new_df['notes_clean'].str.contains('activated', case=False, na=False)]

new_df_filtered = new_df_filtered.rename(columns={'date':'injured'})
new_df_filtered.value_counts()
# Out:
# injured     team      player_name       notes_clean
# 2019-02-25  Warriors  Jacob Evans       placed on il                                   2
# 2017-02-13  Spurs     Bryn Forbes       placed on il                                   1
#             Pacers    Rakeem Christmas  placed on il                                   1
#             Celtics   Jaylen Brown      placed on il with strained right hip flexor    1
#                       Chris Wilcox      placed on il with left achilles tendinitis     1
#                                                                                       ..
# 2008-04-01  Bulls     Drew Gooden       placed on il with abdominal strain             1
#             Bucks     Jake Voskuhl      placed on il with sprained left ankle          1
# 2008-03-31  Pacers    David Harrison    placed on il with illness                      1
#             Jazz      Ronnie Brewer     placed on il with strained right groin         1
# 2008-04-01  Rockets   Loren Woods       placed on il                                   1
# Name: count, Length: 20051, dtype: int64

# %%
# rename columns
new_df = new_df.rename(columns={'date':'date_injured'})
new_df.sort_values(by='player_name')
# Out:
#       date_injured      team                                     player_name  \
# 29351   2019-03-16      Nets
# 19200   2013-03-01     Hawks                              (James) Mike Scott
# 20907   2014-11-12     Hawks                              (James) Mike Scott
# 27582   2018-03-21   Wizards                              (James) Mike Scott
# 29561   2019-04-09     76ers                              (James) Mike Scott
# ...            ...       ...                                             ...
# 35740   2022-04-06  Warriors  placed on IL with right Achilles tendon injury
# 37182   2023-03-04      Jazz          placed on IL with sprained right thumb
# 35742   2022-04-07     Bucks         placed on IL with surgery on right knee
# 32352   2021-04-02   Pistons      placed on IL with torn labrum in right hip
# 36723   2023-01-06    Lakers                  strained left quadriceps (DTD)
#
#                                       notes_clean
# 29351                           activated from il
# 19200                                placed on il
# 20907               placed on il with back injury
# 27582                       placed on il with flu
# 29561   placed on il with tightness in lower back
# ...                                           ...
# 35740                           activated from il
# 37182                           activated from il
# 35742                           activated from il
# 32352                           activated from il
# 36723  placed on il with strained left quadriceps
#
# [37667 rows x 4 columns]

# %%
merged_df = activated.merge(new_df_filtered, on='player_name', how='inner')
merged_df
# Out:
#         activated      team_x   player_name    injured      team_y  \
# 0      1962-11-06     Zephyrs    Al Ferrari 1962-10-25     Zephyrs
# 1      1962-11-06     Zephyrs    Al Ferrari 1962-11-14     Zephyrs
# 2      1969-10-28       Bucks   Bob Greacen 1969-10-15       Bucks
# 3      1972-11-28  Tams (ABA)  Merv Jackson 1972-11-10  Tams (ABA)
# 4      1972-12-16  Tams (ABA)  Randy Denton 1972-11-11  Tams (ABA)
# ...           ...         ...           ...        ...         ...
# 270651 2023-04-16   Grizzlies  Santi Aldama 2022-02-07   Grizzlies
# 270652 2023-04-16   Grizzlies  Santi Aldama 2022-04-09   Grizzlies
# 270653 2023-04-16   Grizzlies  Santi Aldama 2022-04-19   Grizzlies
# 270654 2023-04-16   Grizzlies  Santi Aldama 2022-11-25   Grizzlies
# 270655 2023-04-16   Grizzlies  Santi Aldama 2023-04-07   Grizzlies
#
#                                              notes_clean
# 0                                placed on disabled list
# 1               placed on disabled list with knee injury
# 2                       placed on il with sprained ankle
# 3                                           placed on il
# 4                                           placed on il
# ...                                                  ...
# 270651                 placed on il with sore right foot
# 270652                                      placed on il
# 270653  placed on il with sore right knee out for season
# 270654                         placed on il with illness
# 270655                 placed on il with sore left elbow
#
# [270656 rows x 6 columns]

# %%
# create copy
sort_df = merged_df

# %%
sort_df
# Out:
#         activated      team_x   player_name    injured      team_y  \
# 0      1962-11-06     Zephyrs    Al Ferrari 1962-10-25     Zephyrs
# 1      1962-11-06     Zephyrs    Al Ferrari 1962-11-14     Zephyrs
# 2      1969-10-28       Bucks   Bob Greacen 1969-10-15       Bucks
# 3      1972-11-28  Tams (ABA)  Merv Jackson 1972-11-10  Tams (ABA)
# 4      1972-12-16  Tams (ABA)  Randy Denton 1972-11-11  Tams (ABA)
# ...           ...         ...           ...        ...         ...
# 270651 2023-04-16   Grizzlies  Santi Aldama 2022-02-07   Grizzlies
# 270652 2023-04-16   Grizzlies  Santi Aldama 2022-04-09   Grizzlies
# 270653 2023-04-16   Grizzlies  Santi Aldama 2022-04-19   Grizzlies
# 270654 2023-04-16   Grizzlies  Santi Aldama 2022-11-25   Grizzlies
# 270655 2023-04-16   Grizzlies  Santi Aldama 2023-04-07   Grizzlies
#
#                                              notes_clean
# 0                                placed on disabled list
# 1               placed on disabled list with knee injury
# 2                       placed on il with sprained ankle
# 3                                           placed on il
# 4                                           placed on il
# ...                                                  ...
# 270651                 placed on il with sore right foot
# 270652                                      placed on il
# 270653  placed on il with sore right knee out for season
# 270654                         placed on il with illness
# 270655                 placed on il with sore left elbow
#
# [270656 rows x 6 columns]

# %%
# find closest activaction for potential season ending injuries
# Ensure dates are in datetime format
sort_df['activated'] = pd.to_datetime(sort_df['activated'], errors='coerce')
sort_df['injured'] = pd.to_datetime(sort_df['injured'], errors='coerce')

# filter rows where 'activated' exists and is on or after 'injured' date, for each player
valid_activations = sort_df[
    sort_df['activated'].notna() & (sort_df['activated'] >= sort_df['injured'])
]

# find the closest activation date for each injury by grouping on 'player_name' and 'injured'
closest_activations = (
    valid_activations.groupby(['player_name', 'injured'])['activated']
    .min()
    .reset_index()
    .rename(columns={'activated': 'ClosestActivationDate'})
)

# merge this closest activation date back to the original dataframe
sort_df = sort_df.merge(closest_activations, on=['player_name', 'injured'], how='left')

# handle cases where no activation date exists
sort_df['ClosestActivationDate'] = sort_df['ClosestActivationDate'].fillna('No Activation Date')

sort_df
# Out:
#         activated      team_x   player_name    injured      team_y  \
# 0      1962-11-06     Zephyrs    Al Ferrari 1962-10-25     Zephyrs
# 1      1962-11-06     Zephyrs    Al Ferrari 1962-11-14     Zephyrs
# 2      1969-10-28       Bucks   Bob Greacen 1969-10-15       Bucks
# 3      1972-11-28  Tams (ABA)  Merv Jackson 1972-11-10  Tams (ABA)
# 4      1972-12-16  Tams (ABA)  Randy Denton 1972-11-11  Tams (ABA)
# ...           ...         ...           ...        ...         ...
# 270651 2023-04-16   Grizzlies  Santi Aldama 2022-02-07   Grizzlies
# 270652 2023-04-16   Grizzlies  Santi Aldama 2022-04-09   Grizzlies
# 270653 2023-04-16   Grizzlies  Santi Aldama 2022-04-19   Grizzlies
# 270654 2023-04-16   Grizzlies  Santi Aldama 2022-11-25   Grizzlies
# 270655 2023-04-16   Grizzlies  Santi Aldama 2023-04-07   Grizzlies
#
#                                              notes_clean ClosestActivationDate
# 0                                placed on disabled list   1962-11-06 00:00:00
# 1               placed on disabled list with knee injury    No Activation Date
# 2                       placed on il with sprained ankle   1969-10-28 00:00:00
# 3                                           placed on il   1972-11-28 00:00:00
# 4                                           placed on il   1972-12-16 00:00:00
# ...                                                  ...                   ...
# 270651                 placed on il with sore right foot   2022-02-12 00:00:00
# 270652                                      placed on il   2022-04-10 00:00:00
# 270653  placed on il with sore right knee out for season   2022-11-27 00:00:00
# 270654                         placed on il with illness   2022-11-27 00:00:00
# 270655                 placed on il with sore left elbow   2023-04-16 00:00:00
#
# [270656 rows x 7 columns]

# %%
sort_df['ClosestActivationDate'] = pd.to_datetime(sort_df['ClosestActivationDate'], errors='coerce').dt.date

# %%
sort_df = sort_df.drop(columns=['activated'])

# %%
sort_df = sort_df.rename(columns={'ClosestActivationDate':'activated'})
sort_df = sort_df[['player_name','notes_clean','injured','activated']]
sort_df
# Out:
#          player_name                                       notes_clean  \
# 0         Al Ferrari                           placed on disabled list
# 1         Al Ferrari          placed on disabled list with knee injury
# 2        Bob Greacen                  placed on il with sprained ankle
# 3       Merv Jackson                                      placed on il
# 4       Randy Denton                                      placed on il
# ...              ...                                               ...
# 270651  Santi Aldama                 placed on il with sore right foot
# 270652  Santi Aldama                                      placed on il
# 270653  Santi Aldama  placed on il with sore right knee out for season
# 270654  Santi Aldama                         placed on il with illness
# 270655  Santi Aldama                 placed on il with sore left elbow
#
#           injured   activated
# 0      1962-10-25  1962-11-06
# 1      1962-11-14         NaT
# 2      1969-10-15  1969-10-28
# 3      1972-11-10  1972-11-28
# 4      1972-11-11  1972-12-16
# ...           ...         ...
# 270651 2022-02-07  2022-02-12
# 270652 2022-04-09  2022-04-10
# 270653 2022-04-19  2022-11-27
# 270654 2022-11-25  2022-11-27
# 270655 2023-04-07  2023-04-16
#
# [270656 rows x 4 columns]

# %%
sort_df['activated'] = pd.to_datetime(sort_df['activated'], errors='coerce')

# %%
# get total number of days injured
sort_df['days_injured'] = (sort_df['activated'] - sort_df['injured']).dt.days
sort_df
# Out:
#          player_name                                       notes_clean  \
# 0         Al Ferrari                           placed on disabled list
# 1         Al Ferrari          placed on disabled list with knee injury
# 2        Bob Greacen                  placed on il with sprained ankle
# 3       Merv Jackson                                      placed on il
# 4       Randy Denton                                      placed on il
# ...              ...                                               ...
# 270651  Santi Aldama                 placed on il with sore right foot
# 270652  Santi Aldama                                      placed on il
# 270653  Santi Aldama  placed on il with sore right knee out for season
# 270654  Santi Aldama                         placed on il with illness
# 270655  Santi Aldama                 placed on il with sore left elbow
#
#           injured  activated  days_injured
# 0      1962-10-25 1962-11-06          12.0
# 1      1962-11-14        NaT           NaN
# 2      1969-10-15 1969-10-28          13.0
# 3      1972-11-10 1972-11-28          18.0
# 4      1972-11-11 1972-12-16          35.0
# ...           ...        ...           ...
# 270651 2022-02-07 2022-02-12           5.0
# 270652 2022-04-09 2022-04-10           1.0
# 270653 2022-04-19 2022-11-27         222.0
# 270654 2022-11-25 2022-11-27           2.0
# 270655 2023-04-07 2023-04-16           9.0
#
# [270656 rows x 5 columns]

# %%
sort_df.isnull().sum()
# Out:
# player_name        0
# notes_clean        0
# injured            0
# activated       5325
# days_injured    5325
# dtype: int64

# %% [markdown]
# # Zero-shot classification for injury notes

# %%
# create labels for injuries
def classify_injury_type(note):
    note = note.lower()
    if any(word in note for word in ["muscle", "strain", "pulled", "hamstring", "quad"]):
        return "muscle"
    elif any(word in note for word in ["fracture", "broken", "stress fracture"]):
        return "bone"
    elif any(word in note for word in ["knee", "ankle", "shoulder", "sprain", "ligament", "acl", "mcl"]):
        return "joint"
    elif "concussion" in note or "head" in note:
        return "concussion"
    elif any(word in note for word in ["flu", "illness", "virus", "fever", "cold", "infection"]):
        return "illness"
    else:
        return "unspecified"

# create labels for injury duration
def classify_duration(days):
    if pd.isna(days):
        return "unknown"
    elif days <= 7:
        return "short"
    elif days <= 45:
        return "medium"
    else:
        return "long"

# %%
# apply it to dataset
sort_df["injury_type"] = sort_df["notes_clean"].apply(classify_injury_type)
sort_df["injury_duration"] = sort_df["days_injured"].apply(classify_duration)

# %%
sort_df.head()
# Out:
#     player_name                               notes_clean    injured  \
# 0    Al Ferrari                   placed on disabled list 1962-10-25
# 1    Al Ferrari  placed on disabled list with knee injury 1962-11-14
# 2   Bob Greacen          placed on il with sprained ankle 1969-10-15
# 3  Merv Jackson                              placed on il 1972-11-10
# 4  Randy Denton                              placed on il 1972-11-11
#
#    activated  days_injured  injury_type injury_duration
# 0 1962-11-06          12.0  unspecified          medium
# 1        NaT           NaN        joint         unknown
# 2 1969-10-28          13.0        joint          medium
# 3 1972-11-28          18.0  unspecified          medium
# 4 1972-12-16          35.0  unspecified          medium

# %%
# drop unspecified
unspecified_count = sort_df[sort_df['injury_type'] == 'unspecified'].count()
unspecified_count
# Out:
# player_name        145398
# notes_clean        145398
# injured            145398
# activated          141897
# days_injured       141897
# injury_type        145398
# injury_duration    145398
# dtype: int64

# %%
sort_df = sort_df[sort_df['injury_type'] != 'unspecified']

# %%
sort_df.to_csv('cleaned_data.csv', index=False)
